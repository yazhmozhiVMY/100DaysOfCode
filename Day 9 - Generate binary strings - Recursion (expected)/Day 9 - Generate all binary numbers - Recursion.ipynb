# %% [markdown]
# <div class = "alert alert-block alert-info">
#
#    ### Day 7 problem - using recursion (Expected solution)
# </div>

# %%
myStr = "helllo"
s1 = myStr.replace('l','3')
print("Is the input string modified? "+myStr)
print("modified string "+s1)
# Out:
# Is the input string modified? helllo
# modified string he333o

# %% [markdown]
# ##### No, ther input string is not modified. Store it :) It changes all the occurences of 'l'

# %%
myStr = "helllo"
s1 = myStr.replace('l','3',1)
print(s1)
# Out:
# he3llo

# %% [markdown]
# ##### Changes the first occurence only

# %%
myStr = "helllo"
s2 = myStr.replace('l','3',2)
print(s2)
# Out:
# he33lo

# %% [markdown]
# ##### Changes the first 2 occurences only

# %%
def gen(s):
    if '?' in s:
        s1=s.replace('?','0',1)
        gen(s1)
        s2=s.replace('?','1',1)
        gen(s2)
    else: 
        results.append(s)

# %%
results = []
s = '?1'
gen(s)
print(results)
# Out:
# ['01', '11']

# %%
results = []
s = '1??'
gen(s)
print(results)
# Out:
# ['100', '101', '110', '111']

# %% [markdown]
# <div class = "alert alert-block alert-success">
#
# #### Time = O(2^n)
# #### Space = O(n*2^n)
# n = len of string
# </div>

# %% [markdown]
# ![GenerateBinaryRecursion.jpg](attachment:GenerateBinaryRecursion.jpg)
